# %%
import numpy as np 
import pandas as pd

# %%
# Creating DataFrame using dictonary
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
df = pd.DataFrame(data)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df.shape
# Out:
# (4, 4)

# %%
# Creating DataFrame using list and then adding header-columns
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df2 = pd.DataFrame(data_list)
df2
# Out:
#        0   1         2      3
# 0   John  28  New York  65000
# 1   Anna  34     Paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %%
columns = ["Name","Age","City","Salary"]
df2 = pd.DataFrame(data_list,columns =columns)
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# Selection and Indexing of Columns

# %%
df2[['Name','Salary']]
# Out:
#     Name  Salary
# 0   John   65000
# 1   Anna   70000
# 2  Peter   62000
# 3  Linda   85000

# %%
df2['designation']=['doc','er.','er.',"doc"]
df2
# Out:
#     Name  Age      City  Salary designation
# 0   John   28  New York   65000         doc
# 1   Anna   34     Paris   70000         er.
# 2  Peter   29    Berlin   62000         er.
# 3  Linda   42    London   85000         doc

# %%
# Removing Columns
df2.drop(['designation'],axis=1,inplace=True)
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.loc[[0,2]] #By Indexing
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 2  Peter   29    Berlin   62000

# %%
df2.loc[:1] # By Slicing
# Out:
#    Name  Age      City  Salary
# 0  John   28  New York   65000
# 1  Anna   34     Paris   70000

# %%
df2.iloc[1:3] #Slicing by Indexing
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 2  Peter   29  Berlin   62000

# %% [markdown]
# Selecting Subsets of Rows and Columns

# %%
df.loc[[0,1]][["Age","Salary"]]
# Out:
#    Age  Salary
# 0   28   65000
# 1   34   70000

# %%
df.loc[[2,3]][['Name','Age']]
# Out:
#     Name  Age
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# Conditional Selection

# %%
df[df2['Age']>30] ##I only want to see those people whose age is above 30
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
df[(df2['Age']>30) & (df2['City']=='Paris')] ##I only want poeple whose age is above 30 and their city must be paris
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000
